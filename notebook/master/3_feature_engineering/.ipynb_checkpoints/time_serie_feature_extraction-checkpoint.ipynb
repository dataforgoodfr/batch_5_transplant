# %%
import pandas as pd
from tsfresh import extract_features

# %%
fct_haemodynamic = pd.read_csv('../../../data/fct_haemodynamic.csv')
d = fct_haemodynamic[fct_haemodynamic.id_patient.map(lambda x : x in (381,204))][["fc", "time", "id_patient"]]

# %%
extracted_features = extract_features(fct_haemodynamic[["fc", "time", "id_patient"]], column_id="id_patient", column_sort="time")
# Out:
# Feature Extraction:   0%|          | 0/10 [00:00<?, ?it/s]
# Feature Extraction:  10%|█         | 1/10 [05:32<49:48, 332.00s/it]
# Feature Extraction:  20%|██        | 2/10 [06:16<32:46, 245.84s/it]

# %%
extracted_features
# Out:
# ['fc__abs_energy',
#  'fc__absolute_sum_of_changes',
#  'fc__agg_autocorrelation__f_agg_"mean"',
#  'fc__agg_autocorrelation__f_agg_"median"',
#  'fc__agg_autocorrelation__f_agg_"var"',
#  'fc__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"intercept"',
#  'fc__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"rvalue"',
#  'fc__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"slope"',
#  'fc__agg_linear_trend__f_agg_"max"__chunk_len_10__attr_"stderr"',
#  'fc__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"intercept"',
#  'fc__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"rvalue"',
#  'fc__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"slope"',
#  'fc__agg_linear_trend__f_agg_"max"__chunk_len_50__attr_"stderr"',
#  'fc__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"intercept"',
#  'fc__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"rvalue"',
#  'fc__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"slope"',
#  'fc__agg_linear_trend__f_agg_"max"__chunk_len_5__attr_"stderr"',
#  'fc__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"intercept"',
#  'fc__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"rvalue"',
#  'fc__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"slope"',
#  'fc__agg_linear_trend__f_agg_"mean"__chunk_len_10__attr_"stderr"',
#  'fc__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"intercept"',
#  'fc__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"rvalue"',
#  'fc__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"slope"',
#  'fc__agg_linear_trend__f_agg_"mean"__chunk_len_50__attr_"stderr"',
#  'fc__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"intercept"',
#  'fc__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"rvalue"',
#  'fc__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"slope"',
#  'fc__agg_linear_trend__f_agg_"mean"__chunk_len_5__attr_"stderr"',
#  'fc__agg_linear_trend__f_agg_"min"__chunk_len_10__attr_"intercept"',
#  'fc__agg_linear_trend__f_agg_"min"__chunk_len_10__attr_"rvalue"',
#  'fc__agg_linear_trend__f_agg_"min"__chunk_len_10__attr_"slope"',
#  'fc__agg_linear_trend__f_agg_"min"__chunk_len_10__attr_"stderr"',
#  'fc__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"intercept"',
#  'fc__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"rvalue"',
#  'fc__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"slope"',
#  'fc__agg_linear_trend__f_agg_"min"__chunk_len_50__attr_"stderr"',
#  'fc__agg_linear_trend__f_agg_"min"__chunk_len_5__attr_"intercept"',
#  'fc__agg_linear_trend__f_agg_"min"__chunk_len_5__attr_"rvalue"',
#  'fc__agg_linear_trend__f_agg_"min"__chunk_len_5__attr_"slope"',
#  'fc__agg_linear_trend__f_agg_"min"__chunk_len_5__attr_"stderr"',
#  'fc__agg_linear_trend__f_agg_"var"__chunk_len_10__attr_"intercept"',
#  'fc__agg_linear_trend__f_agg_"var"__chunk_len_10__attr_"rvalue"',
#  'fc__agg_linear_trend__f_agg_"var"__chunk_len_10__attr_"slope"',
#  'fc__agg_linear_trend__f_agg_"var"__chunk_len_10__attr_"stderr"',
#  'fc__agg_linear_trend__f_agg_"var"__chunk_len_50__attr_"intercept"',
#  'fc__agg_linear_trend__f_agg_"var"__chunk_len_50__attr_"rvalue"',
#  'fc__agg_linear_trend__f_agg_"var"__chunk_len_50__attr_"slope"',
#  'fc__agg_linear_trend__f_agg_"var"__chunk_len_50__attr_"stderr"',
#  'fc__agg_linear_trend__f_agg_"var"__chunk_len_5__attr_"intercept"',
#  'fc__agg_linear_trend__f_agg_"var"__chunk_len_5__attr_"rvalue"',
#  'fc__agg_linear_trend__f_agg_"var"__chunk_len_5__attr_"slope"',
#  'fc__agg_linear_trend__f_agg_"var"__chunk_len_5__attr_"stderr"',
#  'fc__approximate_entropy__m_2__r_0.1',
#  'fc__approximate_entropy__m_2__r_0.3',
#  'fc__approximate_entropy__m_2__r_0.5',
#  'fc__approximate_entropy__m_2__r_0.7',
#  'fc__approximate_entropy__m_2__r_0.9',
#  'fc__ar_coefficient__k_10__coeff_0',
#  'fc__ar_coefficient__k_10__coeff_1',
#  'fc__ar_coefficient__k_10__coeff_2',
#  'fc__ar_coefficient__k_10__coeff_3',
#  'fc__ar_coefficient__k_10__coeff_4',
#  'fc__augmented_dickey_fuller__attr_"pvalue"',
#  'fc__augmented_dickey_fuller__attr_"teststat"',
#  'fc__augmented_dickey_fuller__attr_"usedlag"',
#  'fc__autocorrelation__lag_0',
#  'fc__autocorrelation__lag_1',
#  'fc__autocorrelation__lag_2',
#  'fc__autocorrelation__lag_3',
#  'fc__autocorrelation__lag_4',
#  'fc__autocorrelation__lag_5',
#  'fc__autocorrelation__lag_6',
#  'fc__autocorrelation__lag_7',
#  'fc__autocorrelation__lag_8',
#  'fc__autocorrelation__lag_9',
#  'fc__binned_entropy__max_bins_10',
#  'fc__c3__lag_1',
#  'fc__c3__lag_2',
#  'fc__c3__lag_3',
#  'fc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.2__ql_0.0',
#  'fc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.2__ql_0.2',
#  'fc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.2__ql_0.4',
#  'fc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.2__ql_0.6',
#  'fc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.2__ql_0.8',
#  'fc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.4__ql_0.0',
#  'fc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.4__ql_0.2',
#  'fc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.4__ql_0.4',
#  'fc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.4__ql_0.6',
#  'fc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.4__ql_0.8',
#  'fc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.0',
#  'fc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.2',
#  'fc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.4',
#  'fc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.6',
#  'fc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.6__ql_0.8',
#  'fc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.0',
#  'fc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.2',
#  'fc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.4',
#  'fc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.6',
#  'fc__change_quantiles__f_agg_"mean"__isabs_False__qh_0.8__ql_0.8',
#  'fc__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.0',
#  'fc__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.2',
#  'fc__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.4',
#  'fc__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.6',
#  'fc__change_quantiles__f_agg_"mean"__isabs_False__qh_1.0__ql_0.8',
#  'fc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.0',
#  'fc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.2',
#  'fc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.4',
#  'fc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.6',
#  'fc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.2__ql_0.8',
#  'fc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.0',
#  'fc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.2',
#  'fc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.4',
#  'fc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.6',
#  'fc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.4__ql_0.8',
#  'fc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.0',
#  'fc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.2',
#  'fc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.4',
#  'fc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.6',
#  'fc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.6__ql_0.8',
#  'fc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.0',
#  'fc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.2',
#  'fc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.4',
#  'fc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.6',
#  'fc__change_quantiles__f_agg_"mean"__isabs_True__qh_0.8__ql_0.8',
#  'fc__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.0',
#  'fc__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.2',
#  'fc__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.4',
#  'fc__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.6',
#  'fc__change_quantiles__f_agg_"mean"__isabs_True__qh_1.0__ql_0.8',
#  'fc__change_quantiles__f_agg_"var"__isabs_False__qh_0.2__ql_0.0',
#  'fc__change_quantiles__f_agg_"var"__isabs_False__qh_0.2__ql_0.2',
#  'fc__change_quantiles__f_agg_"var"__isabs_False__qh_0.2__ql_0.4',
#  'fc__change_quantiles__f_agg_"var"__isabs_False__qh_0.2__ql_0.6',
#  'fc__change_quantiles__f_agg_"var"__isabs_False__qh_0.2__ql_0.8',
#  'fc__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.0',
#  'fc__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.2',
#  'fc__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.4',
#  'fc__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.6',
#  'fc__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.8',
#  'fc__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.0',
#  'fc__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.2',
#  'fc__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.4',
#  'fc__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.6',
#  'fc__change_quantiles__f_agg_"var"__isabs_False__qh_0.6__ql_0.8',
#  'fc__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.0',
#  'fc__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.2',
#  'fc__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.4',
#  'fc__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.6',
#  'fc__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.8',
#  'fc__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.0',
#  'fc__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.2',
#  'fc__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.4',
#  'fc__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.6',
#  'fc__change_quantiles__f_agg_"var"__isabs_False__qh_1.0__ql_0.8',
#  'fc__change_quantiles__f_agg_"var"__isabs_True__qh_0.2__ql_0.0',
#  'fc__change_quantiles__f_agg_"var"__isabs_True__qh_0.2__ql_0.2',
#  'fc__change_quantiles__f_agg_"var"__isabs_True__qh_0.2__ql_0.4',
#  'fc__change_quantiles__f_agg_"var"__isabs_True__qh_0.2__ql_0.6',
#  'fc__change_quantiles__f_agg_"var"__isabs_True__qh_0.2__ql_0.8',
#  'fc__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.0',
#  'fc__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.2',
#  'fc__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.4',
#  'fc__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.6',
#  'fc__change_quantiles__f_agg_"var"__isabs_True__qh_0.4__ql_0.8',
#  'fc__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.0',
#  'fc__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.2',
#  'fc__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.4',
#  'fc__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.6',
#  'fc__change_quantiles__f_agg_"var"__isabs_True__qh_0.6__ql_0.8',
#  'fc__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.0',
#  'fc__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.2',
#  'fc__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.4',
#  'fc__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.6',
#  'fc__change_quantiles__f_agg_"var"__isabs_True__qh_0.8__ql_0.8',
#  'fc__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.0',
#  'fc__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.2',
#  'fc__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.4',
#  'fc__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.6',
#  'fc__change_quantiles__f_agg_"var"__isabs_True__qh_1.0__ql_0.8',
#  'fc__cid_ce__normalize_False',
#  'fc__cid_ce__normalize_True',
#  'fc__count_above_mean',
#  'fc__count_below_mean',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_10',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_2',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_20',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_0__w_5',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_10',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_2',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_20',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_10__w_5',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_10',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_2',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_20',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_11__w_5',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_10',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_2',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_20',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_12__w_5',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_10',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_2',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_20',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_13__w_5',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_10',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_2',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_20',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_14__w_5',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_10',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_2',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_20',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_1__w_5',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_10',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_2',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_20',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_2__w_5',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_10',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_2',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_20',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_3__w_5',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_10',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_2',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_20',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_4__w_5',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_10',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_2',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_20',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_5__w_5',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_10',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_2',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_20',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_6__w_5',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_10',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_2',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_20',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_7__w_5',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_10',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_2',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_20',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_8__w_5',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_10',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_2',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_20',
#  'fc__cwt_coefficients__widths_(2, 5, 10, 20)__coeff_9__w_5',
#  'fc__energy_ratio_by_chunks__num_segments_10__segment_focus_0',
#  'fc__energy_ratio_by_chunks__num_segments_10__segment_focus_1',
#  'fc__energy_ratio_by_chunks__num_segments_10__segment_focus_2',
#  'fc__energy_ratio_by_chunks__num_segments_10__segment_focus_3',
#  'fc__energy_ratio_by_chunks__num_segments_10__segment_focus_4',
#  'fc__energy_ratio_by_chunks__num_segments_10__segment_focus_5',
#  'fc__energy_ratio_by_chunks__num_segments_10__segment_focus_6',
#  'fc__energy_ratio_by_chunks__num_segments_10__segment_focus_7',
#  'fc__energy_ratio_by_chunks__num_segments_10__segment_focus_8',
#  'fc__energy_ratio_by_chunks__num_segments_10__segment_focus_9',
#  'fc__fft_aggregated__aggtype_"centroid"',
#  'fc__fft_aggregated__aggtype_"kurtosis"',
#  'fc__fft_aggregated__aggtype_"skew"',
#  'fc__fft_aggregated__aggtype_"variance"',
#  'fc__fft_coefficient__coeff_0__attr_"abs"',
#  'fc__fft_coefficient__coeff_0__attr_"angle"',
#  'fc__fft_coefficient__coeff_0__attr_"imag"',
#  'fc__fft_coefficient__coeff_0__attr_"real"',
#  'fc__fft_coefficient__coeff_10__attr_"abs"',
#  'fc__fft_coefficient__coeff_10__attr_"angle"',
#  'fc__fft_coefficient__coeff_10__attr_"imag"',
#  'fc__fft_coefficient__coeff_10__attr_"real"',
#  'fc__fft_coefficient__coeff_11__attr_"abs"',
#  'fc__fft_coefficient__coeff_11__attr_"angle"',
#  'fc__fft_coefficient__coeff_11__attr_"imag"',
#  'fc__fft_coefficient__coeff_11__attr_"real"',
#  'fc__fft_coefficient__coeff_12__attr_"abs"',
#  'fc__fft_coefficient__coeff_12__attr_"angle"',
#  'fc__fft_coefficient__coeff_12__attr_"imag"',
#  'fc__fft_coefficient__coeff_12__attr_"real"',
#  'fc__fft_coefficient__coeff_13__attr_"abs"',
#  'fc__fft_coefficient__coeff_13__attr_"angle"',
#  'fc__fft_coefficient__coeff_13__attr_"imag"',
#  'fc__fft_coefficient__coeff_13__attr_"real"',
#  'fc__fft_coefficient__coeff_14__attr_"abs"',
#  'fc__fft_coefficient__coeff_14__attr_"angle"',
#  'fc__fft_coefficient__coeff_14__attr_"imag"',
#  'fc__fft_coefficient__coeff_14__attr_"real"',
#  'fc__fft_coefficient__coeff_15__attr_"abs"',
#  'fc__fft_coefficient__coeff_15__attr_"angle"',
#  'fc__fft_coefficient__coeff_15__attr_"imag"',
#  'fc__fft_coefficient__coeff_15__attr_"real"',
#  'fc__fft_coefficient__coeff_16__attr_"abs"',
#  'fc__fft_coefficient__coeff_16__attr_"angle"',
#  'fc__fft_coefficient__coeff_16__attr_"imag"',
#  'fc__fft_coefficient__coeff_16__attr_"real"',
#  'fc__fft_coefficient__coeff_17__attr_"abs"',
#  'fc__fft_coefficient__coeff_17__attr_"angle"',
#  'fc__fft_coefficient__coeff_17__attr_"imag"',
#  'fc__fft_coefficient__coeff_17__attr_"real"',
#  'fc__fft_coefficient__coeff_18__attr_"abs"',
#  'fc__fft_coefficient__coeff_18__attr_"angle"',
#  'fc__fft_coefficient__coeff_18__attr_"imag"',
#  'fc__fft_coefficient__coeff_18__attr_"real"',
#  'fc__fft_coefficient__coeff_19__attr_"abs"',
#  'fc__fft_coefficient__coeff_19__attr_"angle"',
#  'fc__fft_coefficient__coeff_19__attr_"imag"',
#  'fc__fft_coefficient__coeff_19__attr_"real"',
#  'fc__fft_coefficient__coeff_1__attr_"abs"',
#  'fc__fft_coefficient__coeff_1__attr_"angle"',
#  'fc__fft_coefficient__coeff_1__attr_"imag"',
#  'fc__fft_coefficient__coeff_1__attr_"real"',
#  'fc__fft_coefficient__coeff_20__attr_"abs"',
#  'fc__fft_coefficient__coeff_20__attr_"angle"',
#  'fc__fft_coefficient__coeff_20__attr_"imag"',
#  'fc__fft_coefficient__coeff_20__attr_"real"',
#  'fc__fft_coefficient__coeff_21__attr_"abs"',
#  'fc__fft_coefficient__coeff_21__attr_"angle"',
#  'fc__fft_coefficient__coeff_21__attr_"imag"',
#  'fc__fft_coefficient__coeff_21__attr_"real"',
#  'fc__fft_coefficient__coeff_22__attr_"abs"',
#  'fc__fft_coefficient__coeff_22__attr_"angle"',
#  'fc__fft_coefficient__coeff_22__attr_"imag"',
#  'fc__fft_coefficient__coeff_22__attr_"real"',
#  'fc__fft_coefficient__coeff_23__attr_"abs"',
#  'fc__fft_coefficient__coeff_23__attr_"angle"',
#  'fc__fft_coefficient__coeff_23__attr_"imag"',
#  'fc__fft_coefficient__coeff_23__attr_"real"',
#  'fc__fft_coefficient__coeff_24__attr_"abs"',
#  'fc__fft_coefficient__coeff_24__attr_"angle"',
#  'fc__fft_coefficient__coeff_24__attr_"imag"',
#  'fc__fft_coefficient__coeff_24__attr_"real"',
#  'fc__fft_coefficient__coeff_25__attr_"abs"',
#  'fc__fft_coefficient__coeff_25__attr_"angle"',
#  'fc__fft_coefficient__coeff_25__attr_"imag"',
#  'fc__fft_coefficient__coeff_25__attr_"real"',
#  'fc__fft_coefficient__coeff_26__attr_"abs"',
#  'fc__fft_coefficient__coeff_26__attr_"angle"',
#  'fc__fft_coefficient__coeff_26__attr_"imag"',
#  'fc__fft_coefficient__coeff_26__attr_"real"',
#  'fc__fft_coefficient__coeff_27__attr_"abs"',
#  'fc__fft_coefficient__coeff_27__attr_"angle"',
#  'fc__fft_coefficient__coeff_27__attr_"imag"',
#  'fc__fft_coefficient__coeff_27__attr_"real"',
#  'fc__fft_coefficient__coeff_28__attr_"abs"',
#  'fc__fft_coefficient__coeff_28__attr_"angle"',
#  'fc__fft_coefficient__coeff_28__attr_"imag"',
#  'fc__fft_coefficient__coeff_28__attr_"real"',
#  'fc__fft_coefficient__coeff_29__attr_"abs"',
#  'fc__fft_coefficient__coeff_29__attr_"angle"',
#  'fc__fft_coefficient__coeff_29__attr_"imag"',
#  'fc__fft_coefficient__coeff_29__attr_"real"',
#  'fc__fft_coefficient__coeff_2__attr_"abs"',
#  'fc__fft_coefficient__coeff_2__attr_"angle"',
#  'fc__fft_coefficient__coeff_2__attr_"imag"',
#  'fc__fft_coefficient__coeff_2__attr_"real"',
#  'fc__fft_coefficient__coeff_30__attr_"abs"',
#  'fc__fft_coefficient__coeff_30__attr_"angle"',
#  'fc__fft_coefficient__coeff_30__attr_"imag"',
#  'fc__fft_coefficient__coeff_30__attr_"real"',
#  'fc__fft_coefficient__coeff_31__attr_"abs"',
#  'fc__fft_coefficient__coeff_31__attr_"angle"',
#  'fc__fft_coefficient__coeff_31__attr_"imag"',
#  'fc__fft_coefficient__coeff_31__attr_"real"',
#  'fc__fft_coefficient__coeff_32__attr_"abs"',
#  'fc__fft_coefficient__coeff_32__attr_"angle"',
#  'fc__fft_coefficient__coeff_32__attr_"imag"',
#  'fc__fft_coefficient__coeff_32__attr_"real"',
#  'fc__fft_coefficient__coeff_33__attr_"abs"',
#  'fc__fft_coefficient__coeff_33__attr_"angle"',
#  'fc__fft_coefficient__coeff_33__attr_"imag"',
#  'fc__fft_coefficient__coeff_33__attr_"real"',
#  'fc__fft_coefficient__coeff_34__attr_"abs"',
#  'fc__fft_coefficient__coeff_34__attr_"angle"',
#  'fc__fft_coefficient__coeff_34__attr_"imag"',
#  'fc__fft_coefficient__coeff_34__attr_"real"',
#  'fc__fft_coefficient__coeff_35__attr_"abs"',
#  'fc__fft_coefficient__coeff_35__attr_"angle"',
#  'fc__fft_coefficient__coeff_35__attr_"imag"',
#  'fc__fft_coefficient__coeff_35__attr_"real"',
#  'fc__fft_coefficient__coeff_36__attr_"abs"',
#  'fc__fft_coefficient__coeff_36__attr_"angle"',
#  'fc__fft_coefficient__coeff_36__attr_"imag"',
#  'fc__fft_coefficient__coeff_36__attr_"real"',
#  'fc__fft_coefficient__coeff_37__attr_"abs"',
#  'fc__fft_coefficient__coeff_37__attr_"angle"',
#  'fc__fft_coefficient__coeff_37__attr_"imag"',
#  'fc__fft_coefficient__coeff_37__attr_"real"',
#  'fc__fft_coefficient__coeff_38__attr_"abs"',
#  'fc__fft_coefficient__coeff_38__attr_"angle"',
#  'fc__fft_coefficient__coeff_38__attr_"imag"',
#  'fc__fft_coefficient__coeff_38__attr_"real"',
#  'fc__fft_coefficient__coeff_39__attr_"abs"',
#  'fc__fft_coefficient__coeff_39__attr_"angle"',
#  'fc__fft_coefficient__coeff_39__attr_"imag"',
#  'fc__fft_coefficient__coeff_39__attr_"real"',
#  'fc__fft_coefficient__coeff_3__attr_"abs"',
#  'fc__fft_coefficient__coeff_3__attr_"angle"',
#  'fc__fft_coefficient__coeff_3__attr_"imag"',
#  'fc__fft_coefficient__coeff_3__attr_"real"',
#  'fc__fft_coefficient__coeff_40__attr_"abs"',
#  'fc__fft_coefficient__coeff_40__attr_"angle"',
#  'fc__fft_coefficient__coeff_40__attr_"imag"',
#  'fc__fft_coefficient__coeff_40__attr_"real"',
#  'fc__fft_coefficient__coeff_41__attr_"abs"',
#  'fc__fft_coefficient__coeff_41__attr_"angle"',
#  'fc__fft_coefficient__coeff_41__attr_"imag"',
#  'fc__fft_coefficient__coeff_41__attr_"real"',
#  'fc__fft_coefficient__coeff_42__attr_"abs"',
#  'fc__fft_coefficient__coeff_42__attr_"angle"',
#  'fc__fft_coefficient__coeff_42__attr_"imag"',
#  'fc__fft_coefficient__coeff_42__attr_"real"',
#  'fc__fft_coefficient__coeff_43__attr_"abs"',
#  'fc__fft_coefficient__coeff_43__attr_"angle"',
#  'fc__fft_coefficient__coeff_43__attr_"imag"',
#  'fc__fft_coefficient__coeff_43__attr_"real"',
#  'fc__fft_coefficient__coeff_44__attr_"abs"',
#  'fc__fft_coefficient__coeff_44__attr_"angle"',
#  'fc__fft_coefficient__coeff_44__attr_"imag"',
#  'fc__fft_coefficient__coeff_44__attr_"real"',
#  'fc__fft_coefficient__coeff_45__attr_"abs"',
#  'fc__fft_coefficient__coeff_45__attr_"angle"',
#  'fc__fft_coefficient__coeff_45__attr_"imag"',
#  'fc__fft_coefficient__coeff_45__attr_"real"',
#  'fc__fft_coefficient__coeff_46__attr_"abs"',
#  'fc__fft_coefficient__coeff_46__attr_"angle"',
#  'fc__fft_coefficient__coeff_46__attr_"imag"',
#  'fc__fft_coefficient__coeff_46__attr_"real"',
#  'fc__fft_coefficient__coeff_47__attr_"abs"',
#  'fc__fft_coefficient__coeff_47__attr_"angle"',
#  'fc__fft_coefficient__coeff_47__attr_"imag"',
#  'fc__fft_coefficient__coeff_47__attr_"real"',
#  'fc__fft_coefficient__coeff_48__attr_"abs"',
#  'fc__fft_coefficient__coeff_48__attr_"angle"',
#  'fc__fft_coefficient__coeff_48__attr_"imag"',
#  'fc__fft_coefficient__coeff_48__attr_"real"',
#  'fc__fft_coefficient__coeff_49__attr_"abs"',
#  'fc__fft_coefficient__coeff_49__attr_"angle"',
#  'fc__fft_coefficient__coeff_49__attr_"imag"',
#  'fc__fft_coefficient__coeff_49__attr_"real"',
#  'fc__fft_coefficient__coeff_4__attr_"abs"',
#  'fc__fft_coefficient__coeff_4__attr_"angle"',
#  'fc__fft_coefficient__coeff_4__attr_"imag"',
#  'fc__fft_coefficient__coeff_4__attr_"real"',
#  'fc__fft_coefficient__coeff_50__attr_"abs"',
#  'fc__fft_coefficient__coeff_50__attr_"angle"',
#  'fc__fft_coefficient__coeff_50__attr_"imag"',
#  'fc__fft_coefficient__coeff_50__attr_"real"',
#  'fc__fft_coefficient__coeff_51__attr_"abs"',
#  'fc__fft_coefficient__coeff_51__attr_"angle"',
#  'fc__fft_coefficient__coeff_51__attr_"imag"',
#  'fc__fft_coefficient__coeff_51__attr_"real"',
#  'fc__fft_coefficient__coeff_52__attr_"abs"',
#  'fc__fft_coefficient__coeff_52__attr_"angle"',
#  'fc__fft_coefficient__coeff_52__attr_"imag"',
#  'fc__fft_coefficient__coeff_52__attr_"real"',
#  'fc__fft_coefficient__coeff_53__attr_"abs"',
#  'fc__fft_coefficient__coeff_53__attr_"angle"',
#  'fc__fft_coefficient__coeff_53__attr_"imag"',
#  'fc__fft_coefficient__coeff_53__attr_"real"',
#  'fc__fft_coefficient__coeff_54__attr_"abs"',
#  'fc__fft_coefficient__coeff_54__attr_"angle"',
#  'fc__fft_coefficient__coeff_54__attr_"imag"',
#  'fc__fft_coefficient__coeff_54__attr_"real"',
#  'fc__fft_coefficient__coeff_55__attr_"abs"',
#  'fc__fft_coefficient__coeff_55__attr_"angle"',
#  'fc__fft_coefficient__coeff_55__attr_"imag"',
#  'fc__fft_coefficient__coeff_55__attr_"real"',
#  'fc__fft_coefficient__coeff_56__attr_"abs"',
#  'fc__fft_coefficient__coeff_56__attr_"angle"',
#  'fc__fft_coefficient__coeff_56__attr_"imag"',
#  'fc__fft_coefficient__coeff_56__attr_"real"',
#  'fc__fft_coefficient__coeff_57__attr_"abs"',
#  'fc__fft_coefficient__coeff_57__attr_"angle"',
#  'fc__fft_coefficient__coeff_57__attr_"imag"',
#  'fc__fft_coefficient__coeff_57__attr_"real"',
#  'fc__fft_coefficient__coeff_58__attr_"abs"',
#  'fc__fft_coefficient__coeff_58__attr_"angle"',
#  'fc__fft_coefficient__coeff_58__attr_"imag"',
#  'fc__fft_coefficient__coeff_58__attr_"real"',
#  'fc__fft_coefficient__coeff_59__attr_"abs"',
#  'fc__fft_coefficient__coeff_59__attr_"angle"',
#  'fc__fft_coefficient__coeff_59__attr_"imag"',
#  'fc__fft_coefficient__coeff_59__attr_"real"',
#  'fc__fft_coefficient__coeff_5__attr_"abs"',
#  'fc__fft_coefficient__coeff_5__attr_"angle"',
#  'fc__fft_coefficient__coeff_5__attr_"imag"',
#  'fc__fft_coefficient__coeff_5__attr_"real"',
#  'fc__fft_coefficient__coeff_60__attr_"abs"',
#  'fc__fft_coefficient__coeff_60__attr_"angle"',
#  'fc__fft_coefficient__coeff_60__attr_"imag"',
#  'fc__fft_coefficient__coeff_60__attr_"real"',
#  'fc__fft_coefficient__coeff_61__attr_"abs"',
#  'fc__fft_coefficient__coeff_61__attr_"angle"',
#  'fc__fft_coefficient__coeff_61__attr_"imag"',
#  'fc__fft_coefficient__coeff_61__attr_"real"',
#  'fc__fft_coefficient__coeff_62__attr_"abs"',
#  'fc__fft_coefficient__coeff_62__attr_"angle"',
#  'fc__fft_coefficient__coeff_62__attr_"imag"',
#  'fc__fft_coefficient__coeff_62__attr_"real"',
#  'fc__fft_coefficient__coeff_63__attr_"abs"',
#  'fc__fft_coefficient__coeff_63__attr_"angle"',
#  'fc__fft_coefficient__coeff_63__attr_"imag"',
#  'fc__fft_coefficient__coeff_63__attr_"real"',
#  'fc__fft_coefficient__coeff_64__attr_"abs"',
#  'fc__fft_coefficient__coeff_64__attr_"angle"',
#  'fc__fft_coefficient__coeff_64__attr_"imag"',
#  'fc__fft_coefficient__coeff_64__attr_"real"',
#  'fc__fft_coefficient__coeff_65__attr_"abs"',
#  'fc__fft_coefficient__coeff_65__attr_"angle"',
#  'fc__fft_coefficient__coeff_65__attr_"imag"',
#  'fc__fft_coefficient__coeff_65__attr_"real"',
#  'fc__fft_coefficient__coeff_66__attr_"abs"',
#  'fc__fft_coefficient__coeff_66__attr_"angle"',
#  'fc__fft_coefficient__coeff_66__attr_"imag"',
#  'fc__fft_coefficient__coeff_66__attr_"real"',
#  'fc__fft_coefficient__coeff_67__attr_"abs"',
#  'fc__fft_coefficient__coeff_67__attr_"angle"',
#  'fc__fft_coefficient__coeff_67__attr_"imag"',
#  'fc__fft_coefficient__coeff_67__attr_"real"',
#  'fc__fft_coefficient__coeff_68__attr_"abs"',
#  'fc__fft_coefficient__coeff_68__attr_"angle"',
#  'fc__fft_coefficient__coeff_68__attr_"imag"',
#  'fc__fft_coefficient__coeff_68__attr_"real"',
#  'fc__fft_coefficient__coeff_69__attr_"abs"',
#  'fc__fft_coefficient__coeff_69__attr_"angle"',
#  'fc__fft_coefficient__coeff_69__attr_"imag"',
#  'fc__fft_coefficient__coeff_69__attr_"real"',
#  'fc__fft_coefficient__coeff_6__attr_"abs"',
#  'fc__fft_coefficient__coeff_6__attr_"angle"',
#  'fc__fft_coefficient__coeff_6__attr_"imag"',
#  'fc__fft_coefficient__coeff_6__attr_"real"',
#  'fc__fft_coefficient__coeff_70__attr_"abs"',
#  'fc__fft_coefficient__coeff_70__attr_"angle"',
#  'fc__fft_coefficient__coeff_70__attr_"imag"',
#  'fc__fft_coefficient__coeff_70__attr_"real"',
#  'fc__fft_coefficient__coeff_71__attr_"abs"',
#  'fc__fft_coefficient__coeff_71__attr_"angle"',
#  'fc__fft_coefficient__coeff_71__attr_"imag"',
#  'fc__fft_coefficient__coeff_71__attr_"real"',
#  'fc__fft_coefficient__coeff_72__attr_"abs"',
#  'fc__fft_coefficient__coeff_72__attr_"angle"',
#  'fc__fft_coefficient__coeff_72__attr_"imag"',
#  'fc__fft_coefficient__coeff_72__attr_"real"',
#  'fc__fft_coefficient__coeff_73__attr_"abs"',
#  'fc__fft_coefficient__coeff_73__attr_"angle"',
#  'fc__fft_coefficient__coeff_73__attr_"imag"',
#  'fc__fft_coefficient__coeff_73__attr_"real"',
#  'fc__fft_coefficient__coeff_74__attr_"abs"',
#  'fc__fft_coefficient__coeff_74__attr_"angle"',
#  'fc__fft_coefficient__coeff_74__attr_"imag"',
#  'fc__fft_coefficient__coeff_74__attr_"real"',
#  'fc__fft_coefficient__coeff_75__attr_"abs"',
#  'fc__fft_coefficient__coeff_75__attr_"angle"',
#  'fc__fft_coefficient__coeff_75__attr_"imag"',
#  'fc__fft_coefficient__coeff_75__attr_"real"',
#  'fc__fft_coefficient__coeff_76__attr_"abs"',
#  'fc__fft_coefficient__coeff_76__attr_"angle"',
#  'fc__fft_coefficient__coeff_76__attr_"imag"',
#  'fc__fft_coefficient__coeff_76__attr_"real"',
#  'fc__fft_coefficient__coeff_77__attr_"abs"',
#  'fc__fft_coefficient__coeff_77__attr_"angle"',
#  'fc__fft_coefficient__coeff_77__attr_"imag"',
#  'fc__fft_coefficient__coeff_77__attr_"real"',
#  'fc__fft_coefficient__coeff_78__attr_"abs"',
#  'fc__fft_coefficient__coeff_78__attr_"angle"',
#  'fc__fft_coefficient__coeff_78__attr_"imag"',
#  'fc__fft_coefficient__coeff_78__attr_"real"',
#  'fc__fft_coefficient__coeff_79__attr_"abs"',
#  'fc__fft_coefficient__coeff_79__attr_"angle"',
#  'fc__fft_coefficient__coeff_79__attr_"imag"',
#  'fc__fft_coefficient__coeff_79__attr_"real"',
#  'fc__fft_coefficient__coeff_7__attr_"abs"',
#  'fc__fft_coefficient__coeff_7__attr_"angle"',
#  'fc__fft_coefficient__coeff_7__attr_"imag"',
#  'fc__fft_coefficient__coeff_7__attr_"real"',
#  'fc__fft_coefficient__coeff_80__attr_"abs"',
#  'fc__fft_coefficient__coeff_80__attr_"angle"',
#  'fc__fft_coefficient__coeff_80__attr_"imag"',
#  'fc__fft_coefficient__coeff_80__attr_"real"',
#  'fc__fft_coefficient__coeff_81__attr_"abs"',
#  'fc__fft_coefficient__coeff_81__attr_"angle"',
#  'fc__fft_coefficient__coeff_81__attr_"imag"',
#  'fc__fft_coefficient__coeff_81__attr_"real"',
#  'fc__fft_coefficient__coeff_82__attr_"abs"',
#  'fc__fft_coefficient__coeff_82__attr_"angle"',
#  'fc__fft_coefficient__coeff_82__attr_"imag"',
#  'fc__fft_coefficient__coeff_82__attr_"real"',
#  'fc__fft_coefficient__coeff_83__attr_"abs"',
#  'fc__fft_coefficient__coeff_83__attr_"angle"',
#  'fc__fft_coefficient__coeff_83__attr_"imag"',
#  'fc__fft_coefficient__coeff_83__attr_"real"',
#  'fc__fft_coefficient__coeff_84__attr_"abs"',
#  'fc__fft_coefficient__coeff_84__attr_"angle"',
#  'fc__fft_coefficient__coeff_84__attr_"imag"',
#  'fc__fft_coefficient__coeff_84__attr_"real"',
#  'fc__fft_coefficient__coeff_85__attr_"abs"',
#  'fc__fft_coefficient__coeff_85__attr_"angle"',
#  'fc__fft_coefficient__coeff_85__attr_"imag"',
#  'fc__fft_coefficient__coeff_85__attr_"real"',
#  'fc__fft_coefficient__coeff_86__attr_"abs"',
#  'fc__fft_coefficient__coeff_86__attr_"angle"',
#  'fc__fft_coefficient__coeff_86__attr_"imag"',
#  'fc__fft_coefficient__coeff_86__attr_"real"',
#  'fc__fft_coefficient__coeff_87__attr_"abs"',
#  'fc__fft_coefficient__coeff_87__attr_"angle"',
#  'fc__fft_coefficient__coeff_87__attr_"imag"',
#  'fc__fft_coefficient__coeff_87__attr_"real"',
#  'fc__fft_coefficient__coeff_88__attr_"abs"',
#  'fc__fft_coefficient__coeff_88__attr_"angle"',
#  'fc__fft_coefficient__coeff_88__attr_"imag"',
#  'fc__fft_coefficient__coeff_88__attr_"real"',
#  'fc__fft_coefficient__coeff_89__attr_"abs"',
#  'fc__fft_coefficient__coeff_89__attr_"angle"',
#  'fc__fft_coefficient__coeff_89__attr_"imag"',
#  'fc__fft_coefficient__coeff_89__attr_"real"',
#  'fc__fft_coefficient__coeff_8__attr_"abs"',
#  'fc__fft_coefficient__coeff_8__attr_"angle"',
#  'fc__fft_coefficient__coeff_8__attr_"imag"',
#  'fc__fft_coefficient__coeff_8__attr_"real"',
#  'fc__fft_coefficient__coeff_90__attr_"abs"',
#  'fc__fft_coefficient__coeff_90__attr_"angle"',
#  'fc__fft_coefficient__coeff_90__attr_"imag"',
#  'fc__fft_coefficient__coeff_90__attr_"real"',
#  'fc__fft_coefficient__coeff_91__attr_"abs"',
#  'fc__fft_coefficient__coeff_91__attr_"angle"',
#  'fc__fft_coefficient__coeff_91__attr_"imag"',
#  'fc__fft_coefficient__coeff_91__attr_"real"',
#  'fc__fft_coefficient__coeff_92__attr_"abs"',
#  'fc__fft_coefficient__coeff_92__attr_"angle"',
#  'fc__fft_coefficient__coeff_92__attr_"imag"',
#  'fc__fft_coefficient__coeff_92__attr_"real"',
#  'fc__fft_coefficient__coeff_93__attr_"abs"',
#  'fc__fft_coefficient__coeff_93__attr_"angle"',
#  'fc__fft_coefficient__coeff_93__attr_"imag"',
#  'fc__fft_coefficient__coeff_93__attr_"real"',
#  'fc__fft_coefficient__coeff_94__attr_"abs"',
#  'fc__fft_coefficient__coeff_94__attr_"angle"',
#  'fc__fft_coefficient__coeff_94__attr_"imag"',
#  'fc__fft_coefficient__coeff_94__attr_"real"',
#  'fc__fft_coefficient__coeff_95__attr_"abs"',
#  'fc__fft_coefficient__coeff_95__attr_"angle"',
#  'fc__fft_coefficient__coeff_95__attr_"imag"',
#  'fc__fft_coefficient__coeff_95__attr_"real"',
#  'fc__fft_coefficient__coeff_96__attr_"abs"',
#  'fc__fft_coefficient__coeff_96__attr_"angle"',
#  'fc__fft_coefficient__coeff_96__attr_"imag"',
#  'fc__fft_coefficient__coeff_96__attr_"real"',
#  'fc__fft_coefficient__coeff_97__attr_"abs"',
#  'fc__fft_coefficient__coeff_97__attr_"angle"',
#  'fc__fft_coefficient__coeff_97__attr_"imag"',
#  'fc__fft_coefficient__coeff_97__attr_"real"',
#  'fc__fft_coefficient__coeff_98__attr_"abs"',
#  'fc__fft_coefficient__coeff_98__attr_"angle"',
#  'fc__fft_coefficient__coeff_98__attr_"imag"',
#  'fc__fft_coefficient__coeff_98__attr_"real"',
#  'fc__fft_coefficient__coeff_99__attr_"abs"',
#  'fc__fft_coefficient__coeff_99__attr_"angle"',
#  'fc__fft_coefficient__coeff_99__attr_"imag"',
#  'fc__fft_coefficient__coeff_99__attr_"real"',
#  'fc__fft_coefficient__coeff_9__attr_"abs"',
#  'fc__fft_coefficient__coeff_9__attr_"angle"',
#  'fc__fft_coefficient__coeff_9__attr_"imag"',
#  'fc__fft_coefficient__coeff_9__attr_"real"',
#  'fc__first_location_of_maximum',
#  'fc__first_location_of_minimum',
#  'fc__friedrich_coefficients__m_3__r_30__coeff_0',
#  'fc__friedrich_coefficients__m_3__r_30__coeff_1',
#  'fc__friedrich_coefficients__m_3__r_30__coeff_2',
#  'fc__friedrich_coefficients__m_3__r_30__coeff_3',
#  'fc__has_duplicate',
#  'fc__has_duplicate_max',
#  'fc__has_duplicate_min',
#  'fc__index_mass_quantile__q_0.1',
#  'fc__index_mass_quantile__q_0.2',
#  'fc__index_mass_quantile__q_0.3',
#  'fc__index_mass_quantile__q_0.4',
#  'fc__index_mass_quantile__q_0.6',
#  'fc__index_mass_quantile__q_0.7',
#  'fc__index_mass_quantile__q_0.8',
#  'fc__index_mass_quantile__q_0.9',
#  'fc__kurtosis',
#  'fc__large_standard_deviation__r_0.05',
#  'fc__large_standard_deviation__r_0.1',
#  'fc__large_standard_deviation__r_0.15000000000000002',
#  'fc__large_standard_deviation__r_0.2',
#  'fc__large_standard_deviation__r_0.25',
#  'fc__large_standard_deviation__r_0.30000000000000004',
#  'fc__large_standard_deviation__r_0.35000000000000003',
#  'fc__large_standard_deviation__r_0.4',
#  'fc__large_standard_deviation__r_0.45',
#  'fc__large_standard_deviation__r_0.5',
#  'fc__large_standard_deviation__r_0.55',
#  'fc__large_standard_deviation__r_0.6000000000000001',
#  'fc__large_standard_deviation__r_0.65',
#  'fc__large_standard_deviation__r_0.7000000000000001',
#  'fc__large_standard_deviation__r_0.75',
#  'fc__large_standard_deviation__r_0.8',
#  'fc__large_standard_deviation__r_0.8500000000000001',
#  'fc__large_standard_deviation__r_0.9',
#  'fc__large_standard_deviation__r_0.9500000000000001',
#  'fc__last_location_of_maximum',
#  'fc__last_location_of_minimum',
#  'fc__length',
#  'fc__linear_trend__attr_"intercept"',
#  'fc__linear_trend__attr_"pvalue"',
#  'fc__linear_trend__attr_"rvalue"',
#  'fc__linear_trend__attr_"slope"',
#  'fc__linear_trend__attr_"stderr"',
#  'fc__longest_strike_above_mean',
#  'fc__longest_strike_below_mean',
#  'fc__max_langevin_fixed_point__m_3__r_30',
#  'fc__maximum',
#  'fc__mean',
#  'fc__mean_abs_change',
#  'fc__mean_change',
#  'fc__mean_second_derivative_central',
#  'fc__median',
#  'fc__minimum',
#  'fc__number_crossing_m__m_-1',
#  'fc__number_crossing_m__m_0',
#  'fc__number_crossing_m__m_1',
#  'fc__number_cwt_peaks__n_1',
#  'fc__number_cwt_peaks__n_5',
#  'fc__number_peaks__n_1',
#  'fc__number_peaks__n_10',
#  'fc__number_peaks__n_3',
#  'fc__number_peaks__n_5',
#  'fc__number_peaks__n_50',
#  'fc__partial_autocorrelation__lag_0',
#  'fc__partial_autocorrelation__lag_1',
#  'fc__partial_autocorrelation__lag_2',
#  'fc__partial_autocorrelation__lag_3',
#  'fc__partial_autocorrelation__lag_4',
#  'fc__partial_autocorrelation__lag_5',
#  'fc__partial_autocorrelation__lag_6',
#  'fc__partial_autocorrelation__lag_7',
#  'fc__partial_autocorrelation__lag_8',
#  'fc__partial_autocorrelation__lag_9',
#  'fc__percentage_of_reoccurring_datapoints_to_all_datapoints',
#  'fc__percentage_of_reoccurring_values_to_all_values',
#  'fc__quantile__q_0.1',
#  'fc__quantile__q_0.2',
#  'fc__quantile__q_0.3',
#  'fc__quantile__q_0.4',
#  'fc__quantile__q_0.6',
#  'fc__quantile__q_0.7',
#  'fc__quantile__q_0.8',
#  'fc__quantile__q_0.9',
#  'fc__range_count__max_1__min_-1',
#  'fc__ratio_beyond_r_sigma__r_0.5',
#  'fc__ratio_beyond_r_sigma__r_1',
#  'fc__ratio_beyond_r_sigma__r_1.5',
#  'fc__ratio_beyond_r_sigma__r_10',
#  'fc__ratio_beyond_r_sigma__r_2',
#  'fc__ratio_beyond_r_sigma__r_2.5',
#  'fc__ratio_beyond_r_sigma__r_3',
#  'fc__ratio_beyond_r_sigma__r_5',
#  'fc__ratio_beyond_r_sigma__r_6',
#  'fc__ratio_beyond_r_sigma__r_7',
#  'fc__ratio_value_number_to_time_series_length',
#  'fc__sample_entropy',
#  'fc__skewness',
#  'fc__spkt_welch_density__coeff_2',
#  'fc__spkt_welch_density__coeff_5',
#  'fc__spkt_welch_density__coeff_8',
#  'fc__standard_deviation',
#  'fc__sum_of_reoccurring_data_points',
#  'fc__sum_of_reoccurring_values',
#  'fc__sum_values',
#  'fc__symmetry_looking__r_0.0',
#  'fc__symmetry_looking__r_0.05',
#  'fc__symmetry_looking__r_0.1',
#  'fc__symmetry_looking__r_0.15000000000000002',
#  'fc__symmetry_looking__r_0.2',
#  'fc__symmetry_looking__r_0.25',
#  'fc__symmetry_looking__r_0.30000000000000004',
#  'fc__symmetry_looking__r_0.35000000000000003',
#  'fc__symmetry_looking__r_0.4',
#  'fc__symmetry_looking__r_0.45',
#  'fc__symmetry_looking__r_0.5',
#  'fc__symmetry_looking__r_0.55',
#  'fc__symmetry_looking__r_0.6000000000000001',
#  'fc__symmetry_looking__r_0.65',
#  'fc__symmetry_looking__r_0.7000000000000001',
#  'fc__symmetry_looking__r_0.75',
#  'fc__symmetry_looking__r_0.8',
#  'fc__symmetry_looking__r_0.8500000000000001',
#  'fc__symmetry_looking__r_0.9',
#  'fc__symmetry_looking__r_0.9500000000000001',
#  'fc__time_reversal_asymmetry_statistic__lag_1',
#  'fc__time_reversal_asymmetry_statistic__lag_2',
#  'fc__time_reversal_asymmetry_statistic__lag_3',
#  'fc__value_count__value_-inf',
#  'fc__value_count__value_0',
#  'fc__value_count__value_1',
#  'fc__value_count__value_inf',
#  'fc__value_count__value_nan',
#  'fc__variance',
#  'fc__variance_larger_than_standard_deviation']
