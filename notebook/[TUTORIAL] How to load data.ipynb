# %% [markdown]
# # How to load data
# This notebook shows how to import data from csvs static and dynamic.

# %%
from transplant.config import PATH_STATIC_CLEAN, PATH_STATIC_CLEAN, DYNAMIC_CATEGORIES, DYNAMIC_CATEGORIES

# %%
# Load the DataFrame
df_static = pd.read_csv(PATH_STATIC_CLEAN)
df_dynamic = pd.read_csv(PATH_STATIC_CLEAN)

# %%
# Print the existing categories 
print("Dynamic categories: %s" % ', '.join(STATIC_CATEGORIES.keys()))
print("\nStatic categories: %s" % ', '.join(DYNAMIC_CATEGORIES.keys()))
# Out:
# Dynamic categories: patient_preoperative, patient_intraoperative, patient_postoperative, donor
#
# Static categories: neurology, haemodynamic, respiratory, temperature

# %%
# Get data from one category
# Example with category "donor"
df_static[STATIC_CATEGORIES['donor']]
# Out:
#      id_patient CMV_donneur EBV_donneur Age_donor Sex_donor  \
# 0             1         NaN         NaN        52         0
# 1             2         NaN         NaN        48         0
# 2             3         NaN         NaN        27         1
# 3             4         NaN         NaN        57         0
# 4             5         NaN         NaN        39         0
# 5             6         NaN         NaN        69         1
# 6             7         NaN         NaN        58         0
# 7             8         NaN         NaN        56         1
# 8             9         NaN         NaN        52         0
# 9            10         NaN         NaN        50         1
# 10           11         NaN         NaN        60         0
# 11           12         NaN         NaN        43         0
# 12           13         NaN         NaN        18         1
# 13           14         NaN         NaN        59         1
# 14           15         NaN         NaN        33         1
# ...
