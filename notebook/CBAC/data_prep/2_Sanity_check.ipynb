# %%
import pandas as pd
import numpy as np
import modules.sanity_check as sc

data = pd.read_csv('../../../data/dim_patient_donor.csv')
data = data.replace("NF", np.nan)

# %%
data_sc = sc.sanity_check(data)
data_sc.full_sc()
# Out:
# <center> <h1> Data quality  check </h1>
# <h2> Metadata : </h2>
# the loaded dataset has  135 rows and 66
# <center> <h3> dataset sample </h3>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id_patient</th>
#       <th>exclusion_plasmapherese</th>
#       <th>exclusion_pf</th>
#       <th>exclusion_ino</th>
#       <th>exclusion_lactate</th>
#       <th>date_transplantation</th>
#       <th>date_sortie_bloc</th>
#       <th>heure_arrivee_rea</th>
#       <th>age</th>
#       <th>sexe</th>
#       <th>body_mass_index</th>
#       <th>diabetes</th>
#       <th>preoperative_icu</th>
#       <th>preoperative_vasopressor</th>
#       <th>preoperative_mechanical_ventilation</th>
#       <th>super_urgence</th>
#       <th>time_on_waiting_liste</th>
#       <th>other_organ_transplantation</th>
#       <th>pathologie</th>
#       <th>retransplant</th>
#       <th>transplanted_twice_during_study_period</th>
# ...
